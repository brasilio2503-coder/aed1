# %% [markdown]
# <a href="https://colab.research.google.com/github/brasilio2503-coder/aed1/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('tamanho')
fps=30
# Out:
# tamanho

# %%
print('tam_video/=1024')
# Out:
# tam_video/=1024

# %%
# Aula3

# %% [markdown]
# #Aula3
# *bites
# **bites
# * item1
