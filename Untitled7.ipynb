# %% [markdown]
# <a href="https://colab.research.google.com/github/brasilio2503-coder/aed1/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('notebook de estudosalgoritmos e programacao com ia')

# %%
print('semana1-introducaoao ambiente deprogramacao')

# %%
print('oi!este e o meu primeiro notebook pyton')

# %%
print('ainda estou aprendendo, mas ja estou conseguindo executar codigo')

# %%
print('notebook:cap01_brasiliodemetrio.ipynb
')

# %%
print('ambiente:google colab/ linguagem:python')
