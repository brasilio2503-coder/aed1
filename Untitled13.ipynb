# %% [markdown]
# <a href="https://colab.research.google.com/github/brasilio2503-coder/aed1/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 65
# 66
# 80

# %%
65
66
67
# Out:
# 67

# %%
ord("A")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_626/2977742631.py in <cell line: 0>()
#       1 ord("A")
# ----> 2 chr("66")
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
ord("B")
# Out:
# 66

# %%
chr("66")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_626/994620106.py in <cell line: 0>()
# ----> 1 chr("66")
#
# TypeError: 'str' object cannot be interpreted as an integer
